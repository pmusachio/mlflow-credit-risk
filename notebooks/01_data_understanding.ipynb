# %% [markdown]
# # MLflow Credit Risk - Data Understanding
#
# Perfil inicial dos dados, schema, nulos, amostras e contrato do projeto.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from mlflow_credit_risk.config import load_config
from mlflow_credit_risk.data import load_training_frame, profile_dataframe
from mlflow_credit_risk.features import prepare_features

config = load_config()
config["project"]

# %%
df = load_training_frame(config)
profile = profile_dataframe(df)
profile['shape'], profile['columns'][:15]

# %%
import pandas as pd
missing = df.isna().mean().sort_values(ascending=False).head(20)
missing.to_frame('missing_share')

# %%
df.head()

# %% [markdown]
# ## Screenshot ideas
#
# - Shape e primeiras colunas do dataset.
# - Tabela de nulos.
# - Amostra dos dados brutos.
