# %% [markdown]
# # MLflow Credit Risk - Feature Engineering
#
# Comparacao entre dados brutos e atributos preparados para modelagem.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from mlflow_credit_risk.config import load_config
from mlflow_credit_risk.data import load_training_frame, profile_dataframe
from mlflow_credit_risk.features import prepare_features

config = load_config()
config["project"]

# %%
df = load_training_frame(config)
features = prepare_features(df.copy(), config)
print('raw shape:', df.shape)
print('feature shape:', features.shape)
features.head()

# %%
new_columns = sorted(set(features.columns) - set(df.columns))
new_columns[:50], len(new_columns)

# %% [markdown]
# ## Feature rationale
#
# - Pipeline supervisionado para variaveis de comportamento de credito.
# - Metrica principal orientada a ordenacao de risco.
# - Registro opcional de parametros, metricas e artefatos no MLflow.
