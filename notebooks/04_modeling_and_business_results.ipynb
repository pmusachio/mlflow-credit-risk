# %% [markdown]
# # MLflow Credit Risk - Modeling and Business Results
#
# Pipeline execution, metrics read-out, and business translation.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from mlflow_credit_risk.config import load_config
from mlflow_credit_risk.data import load_training_frame, profile_dataframe
from mlflow_credit_risk.features import prepare_features

config = load_config()
config["project"]

# %%
RUN_PIPELINE = False

if RUN_PIPELINE:
    from mlflow_credit_risk.cli import main
    main(['train'])
else:
    print('Defina RUN_PIPELINE = True para executar o fluxo neste notebook.')

# %%
from pathlib import Path
import json

for path in [Path('reports/metrics.json'), Path('reports/ab_test_results.json')]:
    if path.exists():
        display(json.loads(path.read_text()))

if Path('reports/price_elasticity.csv').exists():
    import pandas as pd
    display(pd.read_csv('reports/price_elasticity.csv').head(20))

# %% [markdown]
# ## Business Translation
#
# The score supports credit policy with risk-based cutoffs and an auditable experiment trail.

# %% [markdown]
# ## Next Steps
#
# - Add a decision matrix by score band.
# - Compare models with MLflow UI tracking.
# - Build temporal validation to simulate credit vintages.
